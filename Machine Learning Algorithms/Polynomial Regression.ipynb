# %%
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

filepath = "C:\\Users\\Aung Thiha\\Machine Learning With Python\\Machine Learning DataSets (csv format)\\auto-mpg.csv"
df = pd.read_csv(filepath)

print(df.isnull().sum())

new_df = df.drop(["car name"],axis="columns")

inputs = new_df.drop(["horsepower","acceleration"],axis="columns")
target = new_df["acceleration"]

poly = PolynomialFeatures(degree = 5)
polyfit = poly.fit_transform(inputs)
model = LinearRegression()
model.fit(polyfit,target)
print("Training Data is finished")

print("Predict Value is ",model.predict(polyfit[[393]]))
#print(df["acceleration"].values[393])

print("Accurancy score is",model.score(polyfit,target))
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64
# Training Data is finished
# Predict Value is  [16.20672607]
# Accurancy score is 0.8889556228170086

# %% [markdown]
# ### Data Visualization

# %%
plt.scatter(inputs["mpg"], target, color='red')
plt.scatter(inputs["mpg"], model.predict(polyfit), color='blue')
plt.title('Polynomial Linear Regression')
plt.xlabel('mpg')
plt.ylabel('Acceleration !')
plt.show()
